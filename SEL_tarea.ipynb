# %% [markdown]
# <a href="https://colab.research.google.com/github/jcjimenezb123/MetodosNumericosPython/blob/master/SEL_tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![destilacion.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# El p-xileno, estireno, tolueno y benceno se separan en la siguiente secuencia de columnas de destilación.
#
# Calcule el flujo molar de las corrientes $D_1$, $D_2$, $B_1$ y $B_2$.
