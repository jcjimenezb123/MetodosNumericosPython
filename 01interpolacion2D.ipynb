# %% [markdown]
# <a href="https://colab.research.google.com/github/jcjimenezb123/MetodosNumericosPython/blob/master/01interpolacion2D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# La siguiente información muestra la Entalpía de vapor supercalentado a distintas temperaturas y presiones, use la interpolación en dos dimensiones para estimar la Entalpía a 420K y 190Kpa
#
# $$
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# \text{Presión\Temperatura}&300 &350 &400 &450 &500\\
# \hline
# 150 &3073.3 &3174.7 &3277.5 &3381.7 &3487.6\\
# 200 &3072.1 &3173.8 &3276.7 &3381.1 &3487.0\\
# 250 &3070.9 &3172.8 &3275.9 &3380.4 &3486.5\\
# 300 &3069.7 &3171.9 &3275.2 &3379.8 &3486.0\\
# \hline
# \end{array}
# $$

# %%
import numpy as np
from scipy.interpolate import RectBivariateSpline
import matplotlib.pyplot as plt

# %%
x=np.array ([300 ,350 ,400 ,450 ,500]) #temperatura
y=np.array ([150 ,200 ,250 ,300]) #presion
#entalpia
z=np.array ([[3073.3 ,3174.7 ,3277.5 ,3381.7 ,3487.6] ,\
              [3072.1 ,3173.8 ,3276.7 ,3381.1 ,3487.0] ,\
              [3070.9 ,3172.8 ,3275.9 ,3380.4 ,3486.5] ,\
              [3069.7 ,3171.9 ,3275.2 ,3379.8 ,3486.0]])

# %%
pol_inter2d=RectBivariateSpline(x, y, z.T, kx=3, ky=3) #interpolacion spline cubico kx=3 ky=3
xi=420 #temperatura a interpolar
yi=190 #presion a interpolar
zi=pol_inter2d(xi,yi) #entalpia interpolada
print(zi)
# Out:
# [[3318.426752]]

# %%
x,y=np.meshgrid(x,y)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot_surface(x,y,z,cmap='coolwarm')
ax.scatter(xi,yi,zi,color='magenta')
ax.set_title('Entalpía de vapor supercalentado')
ax.set_xlabel('Temperatura')
ax.set_ylabel('Presión')
ax.set_zlabel('Entalpía')
#ax.view_init(elev=30,azim=-40)
plt.show()
